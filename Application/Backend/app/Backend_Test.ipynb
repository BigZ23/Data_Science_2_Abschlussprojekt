# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: fastai==2.7.13 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ../requirements.txt (line 1)) (2.7.13)
# Collecting fastapi==0.109.0 (from -r ../requirements.txt (line 2))
#   Using cached fastapi-0.109.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: geopandas==0.13.2 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ../requirements.txt (line 3)) (0.13.2)
# Collecting matplotlib==3.7.0 (from -r ../requirements.txt (line 4))
#   Using cached matplotlib-3.7.0-cp310-cp310-win_amd64.whl (7.6 MB)
# Collecting numpy==1.23.5 (from -r ../requirements.txt (line 5))
#   Using cached numpy-1.23.5-cp310-cp310-win_amd64.whl (14.6 MB)
# Collecting osmnx==1.8.1 (from -r ../requirements.txt (line 6))
#   Using cached osmnx-1.8.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting Pillow==10.2.0 (from -r ../requirements.txt (line 7))
#   Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: Requests==2.31.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ../requirements.txt (line 8)) (2.31.0)
# Collecting starlette==0.35.1 (from -r ../requirements.txt (line 9))
#   Downloading starlette-0.35.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pip in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (23.3.2)
# Requirement already satisfied: packaging in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (23.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (0.16.1)
# Requirement already satisfied: pandas in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pyyaml in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (1.0.3)
# Requirement already satisfied: scikit-learn in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: scipy in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: spacy<4 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (3.7.2)
# Requirement already satisfied: torch<2.2,>=1.10 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai==2.7.13->-r ../requirements.txt (line 1)) (2.1.1+cu118)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastapi==0.109.0->-r ../requirements.txt (line 2)) (2.5.2)
# Collecting typing-extensions>=4.8.0 (from fastapi==0.109.0->-r ../requirements.txt (line 2))
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geopandas==0.13.2->-r ../requirements.txt (line 3)) (1.9.4.post1)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geopandas==0.13.2->-r ../requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geopandas==0.13.2->-r ../requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib==3.7.0->-r ../requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from osmnx==1.8.1->-r ../requirements.txt (line 6)) (3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Requests==2.31.0->-r ../requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Requests==2.31.0->-r ../requirements.txt (line 8)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Requests==2.31.0->-r ../requirements.txt (line 8)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Requests==2.31.0->-r ../requirements.txt (line 8)) (2022.6.15)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from starlette==0.35.1->-r ../requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<5,>=3.4.0->starlette==0.35.1->-r ../requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<5,>=3.4.0->starlette==0.35.1->-r ../requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (8.1.6)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: six in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->fastai==2.7.13->-r ../requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->fastai==2.7.13->-r ../requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.109.0->-r ../requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.109.0->-r ../requirements.txt (line 2)) (2.14.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (4.64.0)
# Requirement already satisfied: jinja2 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: filelock in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: sympy in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.12)
# Requirement already satisfied: fsspec in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai==2.7.13->-r ../requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->fastai==2.7.13->-r ../requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: colorama in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click~=8.0->fiona>=1.8.19->geopandas==0.13.2->-r ../requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->spacy<4->fastai==2.7.13->-r ../requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\wiess\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch<2.2,>=1.10->fastai==2.7.13->-r ../requirements.txt (line 1)) (1.3.0)
# Downloading fastapi-0.109.0-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ----------------------------------- ---- 81.9/92.0 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 92.0/92.0 kB 1.3 MB/s eta 0:00:00
# Downloading osmnx-1.8.1-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#    ---------------------------------------- 102.8/102.8 kB 2.0 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.6 MB 2.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/2.6 MB 2.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.6 MB 2.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/2.6 MB 2.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.6 MB 2.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.6 MB 2.0 MB/s eta 0:00:02
#    --------- ------------------------------ 0.6/2.6 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.7/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 2.0 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.6 MB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 2.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 1.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.2/2.6 MB 2.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 2.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.6 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.7 MB/s eta 0:00:00
# Downloading starlette-0.35.1-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.1 kB ? eta -:--:--
#    ---------------------------------------- 71.1/71.1 kB 1.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: typing-extensions, Pillow, numpy, starlette, matplotlib, fastapi, osmnx
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 10.0.0
#     Uninstalling Pillow-10.0.0:
#       Successfully uninstalled Pillow-10.0.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: osmnx
#     Found existing installation: osmnx 1.8.0
#     Uninstalling osmnx-1.8.0:
#       Successfully uninstalled osmnx-1.8.0
# Successfully installed Pillow-10.2.0 fastapi-0.109.0 matplotlib-3.7.0 numpy-1.23.5 osmnx-1.8.1 starlette-0.35.1 typing-extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastai.vision.all import *
import os
import math
import geopandas as gpd
import matplotlib.pyplot as plt
from PIL import Image
import osmnx as ox
import osmnx as ox
import shutil

# %% [markdown]
# Code to calculate the bounds of a given center point and zoom level on google maps (modified from [here](https://stackoverflow.com/questions/12507274/how-to-get-bounds-of-a-google-static-map))

# %%
def latLngToPoint(mapWidth, mapHeight, lat, lng):
    x = (lng + 180) * (mapWidth / 360)

    y = ((1 - math.log(math.tan(lat * math.pi / 180) + 1 / math.cos(lat * math.pi / 180)) / math.pi) / 2) * mapHeight

    return (x, y)



def pointToLatLng(mapWidth, mapHeight, x, y):
    lng = x / mapWidth * 360 - 180
    n = math.pi - 2 * math.pi * y / mapHeight
    lat = 180 / math.pi * math.atan(0.5 * (math.exp(n) - math.exp(-n)))


    return (lat, lng)



def getImageBounds(lat, lng, zoom):
    picHeight = 640
    picWidth = 640


    mapHeight = 256
    mapWidth = 256


    xScale = math.pow(2, zoom) / (picWidth / mapWidth)
    yScale = math.pow(2, zoom) / (picHeight / mapWidth)


    centreX, centreY = latLngToPoint(mapWidth, mapHeight, lat, lng)


    southWestX = centreX - (mapWidth / 2) / xScale
    southWestY = centreY + (mapHeight / 2) / yScale
    SWlat, SWlng = pointToLatLng(mapWidth, mapHeight, southWestX, southWestY)


    northEastX = centreX + (mapWidth / 2) / xScale
    northEastY = centreY - (mapHeight / 2) / yScale
    NElat, NElng = pointToLatLng(mapWidth, mapHeight, northEastX, northEastY)


    return [SWlat, SWlng, NElat, NElng]

# %%
# list all landuse to later classify
dictionary_landuse = [
    "not_assigned",
    "commercial",
    "construction",
    "education",
    "fairground",
    "industrial",
    "residential",
    "retail",
    "institutional",
    "aquaculture",
    "allotments",
    "farmland",
    "farmyard",
    "paddy",
    "animal_keeping",
    "flowerbed",
    "forest",
    "greenhouse_horticulture",
    "meadow",
    "orchard",
    "plant_nursery",
    "vineyard",
    "basin",
    "salt_pond",
    "brownfield",
    "cemetery",
    "depot",
    "garages",
    "grass",
    "greenfield",
    "landfill",
    "military",
    "port",
    "quarry",
    "railway",
    "recreation_ground",
    "religious",
    "village_green",
    "winter_sports",
]

# %%
# map each landuse to a distinct color
landuse_mapped_hex = {
    "not_assigned": "#FFFFFF",
    "commercial": "#2F4F4F",
    "construction": "#556B2F",
    "education": "#A0522D",
    "fairground": "#006400",
    "industrial": "#8B0000",
    "residential": "#808000",
    "retail": "#483D8B",
    "institutional": "#778899",
    "aquaculture": "#BC8F8F",
    "allotments": "#008B8B",
    "farmland": "#00008B",
    "farmyard": "#32CD32",
    "paddy": "#DAA520",
    "animal_keeping": "#8FB88F",
    "flowerbed": "#8B008B",
    "forest": "#B03060",
    "greenhouse_horticulture": "#FF0000",
    "meadow": "#FF8C00",
    "orchard": "#FFFF00",
    "plant_nursery": "#0000CD",
    "vineyard": "#40E0D0",
    "basin": "#00FF00",
    "salt_pond": "#DC143C",
    "brownfield": "#00BFFF",
    "cemetery": "#A020F0",
    "depot": "#F08080",
    "garages": "#ADFF2F",
    "grass": "#DA70D6",
    "greenfield": "#FF7F50",
    "landfill": "#FF00FF",
    "military": "#F0E68C",
    "port": "#6495ED",
    "quarry": "#DDA0DD",
    "railway": "#B0E0E6",
    "recreation_ground": "#90EE90",
    "religious": "#FF1493",
    "village_green": "#7B68EE",
    "winter_sports": "#FFDAB9",
}

# %%
#map each label to it's value as rgb array
landuse_mapped_rgb = {
0: [255, 255, 255],        # "not_assigned"
1: [47, 79, 79],           # "commercial"
2: [85, 107, 47],          # "construction"
3: [160, 82, 45],          # "education"
4: [0, 100, 0],            # "fairground"
5: [139, 0, 0],            # "industrial"
6: [128, 128, 0],          # "residential"
7: [72, 61, 139],          # "retail"
8: [119, 136, 153],        # "institutional"
9: [188, 143, 143],        # "aquaculture"
10: [0, 139, 139],         # "allotments"
11: [0, 0, 139],           # "farmland"
12: [50, 205, 50],         # "farmyard"
13: [218, 165, 32],        # "paddy"
14: [143, 184, 143],       # "animal_keeping"
15: [139, 0, 139],         # "flowerbed"
16: [176, 48, 96],         # "forest"
17: [255, 0, 0],           # "greenhouse_horticulture"
18: [255, 140, 0],         # "meadow"
19: [255, 255, 0],         # "orchard"
20: [0, 0, 205],           # "plant_nursery"
21: [64, 224, 208],        # "vineyard"
22: [0, 255, 0],           # "basin"
23: [220, 20, 60],         # "salt_pond"
24: [0, 191, 255],         # "brownfield"
25: [160, 32, 240],        # "cemetery"
26: [240, 128, 128],       # "depot"
27: [173, 255, 47],        # "garages"
28: [218, 112, 214],       # "grass"
29: [255, 127, 80],        # "greenfield"
30: [255, 0, 255],         # "landfill"
31: [240, 230, 140],       # "military"
32: [100, 149, 237],       # "port"
33: [221, 160, 221],       # "quarry"
34: [176, 224, 230],       # "railway"
35: [144, 238, 144],       # "recreation_ground"
36: [255, 20, 147],        # "religious"
37: [123, 104, 238],       # "village_green"
38: [255, 218, 185]        # "winter_sports"
}

# %%
landuse_mapped_rgb[0]
# Out:
# [255, 255, 255]

# %%
# defining all data paths
path = Path("Data")
image_path = path / "Images"
mask_path = path / "Masks"

# %%
# function to get the mask given an image
def get_mask(x):
    # load the numpyfile
    numpyfile = np.load(mask_path / f"{x.stem}.npz")
    # access the data stored in the compressed file format
    data = numpyfile.f.arr_0
    # close the file as to save memory
    numpyfile.close()
    # return the extracted mask
    return data

# %%
# Function for custom metric to not include non-assigned area in metric.
# Don't punish the missclassification of originaly non-assigned area and don't reward the "correct" classification of non-assigned area
# Reasoning: non-assigned area is not a real classification, but an arifact of missing data
def dice_wo_bg(input, target):

    input = (input.argmax(dim=1) != 0).float()
    target = (target.squeeze(1) != 0).float()

    return (2.0 * (input * target).sum().float() + 1e-8) / (input.sum().float() + target.sum().float() + 1e-8)

# %%
# Function to plot the openstreetmap data and save it as a .png
def plot_data(coordinates, zoom=16):
    # get the bounding box form the given coordinates and zoom level
    south, east, north, west = getImageBounds(
        float(coordinates[0]), float(coordinates[1]), zoom
    )

    # query openstreetmap for all landuse in the boundingbox
    landuse = ox.features_from_bbox(north, south, east, west, tags={"landuse": True})

    # create a plot
    fig, ax = plt.subplots(figsize=(8, 8), dpi=104)

    # for each landuse in the queried data, color the respective area in the earlier specified color
    for type in landuse["landuse"].unique():
        # filter so wrongly labeled data doesn't cause any issues (instances of this can be seen on the openstreetmap key wiki)
        if type in dictionary_landuse:
            # filter for the currently selected landuse and plot it.
            landuse.loc[landuse["landuse"] == type].plot(
                ax=ax,
                color=landuse_mapped_hex[type],
                antialiased=False,
                edgecolor="none",
            )
    plt.xlim(east, west)
    plt.ylim(south, north)
    # turn of the axis, as to not save it in the image file
    plt.axis("off")
    # save the image file under the specified path
    fig.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png", bbox_inches="tight", pad_inches=0,)
    # close the plot to reduce memory usage
    plt.close()
    # open the image again
    rgb_converted = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png")
    # convert it from rgba to rgb as we are not using the alpha values
    rgb_converted = rgb_converted.convert("RGB")
    # save it again
    rgb_converted.save(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png")

# %%
import requests
import shutil
import os


# function to donwload images from the googlestaticmap api
def download_images(coordinates, zoom=16):
    # define the request parameters
    url = "https://maps.googleapis.com/maps/api/staticmap?"
    api_key = "AIzaSyAnTP0O9HhzodzG1DTFhk0T9tOfcYxFfvc"
    size = "640x640"
    scale = "1"
    maptype = "satellite"

    # pose get request
    response = requests.get(url + "center=" + str(coordinates[0]) + "," + str(coordinates[1]) + "&zoom=" + str(zoom) + "&size=" + size + "&maptype=" + maptype + "&scale=" + scale + "&sensor=false" + "&key=" + api_key, stream=True,)
    # stream repsonse into file and save it
    with open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + ".png", "wb",) as out_file:
        shutil.copyfileobj(response.raw, out_file)
    # delete the repsonse arifact
    del response

# %%
def prediction(coordinates):
    download_images(coordinates, 16)
    plot_data(coordinates, 16)
    learn = load_learner(os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd()))) + os.sep + "Model" + os.sep + "model.pkl", cpu=False,)
    prediction = learn.predict(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + ".png")
    return prediction

# %%
prediction_data = prediction((39.6290551, 2.7241145))
data = prediction_data[0]
data = np.array(data)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
def plot_prediction(coordinates, prediction):
    scale = 3
    data_rgb = np.zeros((len(prediction) * scale, len(prediction) * scale, 3))
    for line in range(len(prediction)):
        for column in range(len(prediction)):
            for x in range(scale):
                for y in range(scale):
                    data_rgb[(line * scale) + x][
                        (column * scale) + y
                    ] = landuse_mapped_rgb[prediction[line][column]]
    data_rgb = data_rgb.astype(int)
    plt.subplots(figsize=(8, 8), dpi=104)
    plt.plot(antialiased=False)
    plt.imshow(data_rgb, interpolation="none")
    # turn of the axis, as to not save it in the image file
    plt.axis("off")
    # save the image file under the specified path
    plt.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png", bbox_inches="tight", pad_inches=0,)
    # close the plot to reduce memory usage
    plt.close()
    # open the image again
    rgb_converted = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png")
    # convert it from rgba to rgb as we are not using the alpha values
    rgb_converted = rgb_converted.convert("RGB")
    # save it again
    rgb_converted.save(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png")

# %%
def plot_combined(coordinates, prediction):
    osm_data = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png")
    prediction_data = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png")
    osm_data = np.array(osm_data)
    prediction_data = np.array(prediction_data)
    combined_array = np.zeros((len(osm_data), len(osm_data), 3))
    for line in range(len(osm_data)):
        for column in range(len(osm_data)):
            if np.array_equal(osm_data[line][column], [255, 255, 255]):
                combined_array[line][column] = prediction_data[line][column]
            else:
                combined_array[line][column] = osm_data[line][column]
    combined_array = combined_array.astype(int)
    plt.subplots(figsize=(8, 8), dpi=104)
    plt.plot(antialiased=False)
    plt.imshow(combined_array, interpolation="none")
    # turn of the axis, as to not save it in the image file
    plt.axis("off")
    # save the image file under the specified path
    plt.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png", bbox_inches="tight", pad_inches=0,)
    # close the plot to reduce memory usage
    plt.close()
    # open the image again
    rgb_converted = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png")
    # convert it from rgba to rgb as we are not using the alpha values
    rgb_converted = rgb_converted.convert("RGB")
    # save it again
    rgb_converted.save(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png")

# %%
# Code from https://stackoverflow.com/questions/15857647/how-to-export-plots-from-matplotlib-with-transparent-background to make non-assigned white area transparent
def white_to_transparency(img):
    x = np.asarray(img.convert('RGBA')).copy()

    x[:, :, 3] = (255 * (x[:, :, :3] != 255).any(axis=2)).astype(np.uint8)

    return Image.fromarray(x)

# %%
def add_background(coordinates):
    #add background to combined mask
    plt.subplots(figsize=(8, 8), dpi=104)
    plt.plot(antialiased=True)
    plt.imshow(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + ".png"), alpha=1)
    plt.imshow(white_to_transparency(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png")), alpha=0.8)
    plt.axis("off")
    plt.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png", bbox_inches="tight", pad_inches=0,)
    plt.close()
    
    #add background to osm mask
    plt.subplots(figsize=(8, 8), dpi=104)
    plt.plot(antialiased=True)
    plt.imshow(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + ".png"), alpha=1)
    plt.imshow(white_to_transparency(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png")), alpha=0.8)
    plt.axis("off")
    plt.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_OSM_Data" + ".png", bbox_inches="tight", pad_inches=0,)
    plt.close()
    
    #add background to predicted mask
    plt.subplots(figsize=(8, 8), dpi=104)
    plt.plot(antialiased=True)
    plt.imshow(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + ".png"), alpha=1)
    plt.imshow(white_to_transparency(Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png")), alpha=0.8)
    plt.axis("off")
    plt.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Prediction" + ".png", bbox_inches="tight", pad_inches=0,)
    plt.close()

# %%
# Function to plot the openstreetmap street data and save it as a .png
def plot_streets(coordinates, zoom=16):
    # get the bounding box form the given coordinates and zoom level
    south, east, north, west = getImageBounds(
        float(coordinates[0]), float(coordinates[1]), zoom
    )

    # query openstreetmap for all streets in the boundingbox
    streets = ox.features_from_bbox(north, south, east, west, tags={"highway": True})

    # create a plot
    fig, ax = plt.subplots(figsize=(8, 8), dpi=104)

    streets.plot(
            ax=ax,
            color = "#000000",
            antialiased=False,
            edgecolor="none",
            )
    
    plt.xlim(east, west)
    plt.ylim(south, north)
    # turn of the axis, as to not save it in the image file
    plt.axis("off")
    # save the image file under the specified path
    fig.savefig(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Street_Data" + ".png", bbox_inches="tight", pad_inches=0,)
    # close the plot to reduce memory usage
    plt.close()
    # open the image again
    rgb_converted = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Street_Data" + ".png")
    # convert it from rgba to rgb as we are not using the alpha values
    rgb_converted = rgb_converted.convert("RGB")
    # save it again
    rgb_converted.save(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Street_Data" + ".png")

# %%
valid_rgb = ['255255255', '477979', '8510747', '1608245', '01000', 
 '13900', '1281280', '7261139', '119136153', '188143143', 
 '0139139', '00139', '5020550', '21816532', '143184143', 
 '13900139', '1764896', '25500', '2551400', '2552550', 
 '000205', '64224208', '002550', '2202060', '0191255', 
 '16032240', '240128128', '17325547', '218112214', 
 '25512780', '2550255', '240230140', '100149237', 
 '221160221', '176224230', '144238144', '25520147', 
 '123104238', '255218185']

# %%
hex_value = ['#FFFFFF', '#2F4F4F', '#556B2F', '#A0522D', '#006400', '#8B0000', '#808000', '#483D8B',
 '#778899', '#BC8F8F', '#008B8B', '#00008B', '#32CD32', '#DAA520', '#8FB88F', '#8B008B',
 '#B03060', '#FF0000', '#FF8C00', '#FFFF00', '#0000CD', '#40E0D0', '#00FF00', '#DC143C',
 '#00BFFF', '#A020F0', '#F08080', '#ADFF2F', '#DA70D6', '#FF7F50', '#FF00FF', '#F0E68C',
 '#6495ED', '#DDA0DD', '#B0E0E6', '#90EE90', '#FF1493', '#7B68EE', '#FFDAB9']

# %%
def get_unique(coordinates):
    image = Image.open(os.getcwd() + os.sep + "temp" + os.sep + str(coordinates[0]) + "_" + str(coordinates[1]) + "_Combined" + ".png")
    image_data = np.array(image)
    image_data_reshape = image_data.reshape((-1, 3))
    unique = np.unique(image_data_reshape, axis=0)
    valid_unique = []
    for element in unique:
        value = ''.join(str(x) for x in element)
        if value in valid_rgb:
            valid_unique.append(valid_rgb.index(value))
    valid_unique.sort()
    return valid_unique
